# %%
import pandas as pd

# %%
#read dataset
df = pd.read_csv(r'Border_Crossing_Entry_Data.csv')

# %%
#see the first 15 entries
df.head(15)
# Out:
#                  Port Name         State  Port Code            Border  \
# 0            Calexico East    California       2507  US-Mexico Border
# 1                Van Buren         Maine        108  US-Canada Border
# 2                Otay Mesa    California       2506  US-Mexico Border
# 3                  Nogales       Arizona       2604  US-Mexico Border
# 4              Trout River      New York        715  US-Canada Border
# 5                Madawaska         Maine        109  US-Canada Border
# 6                  Pembina  North Dakota       3401  US-Canada Border
# 7                 Progreso         Texas       2309  US-Mexico Border
# 8                   Portal  North Dakota       3403  US-Canada Border
# 9   Champlain-Rouses Point      New York        712  US-Canada Border
# 10                  Opheim       Montana       3317  US-Canada Border
# 11                   Neche  North Dakota       3404  US-Canada Border
# ...

# %%
#see the last 10 entries
df.tail(10)
# Out:
#             Port Name         State  Port Code            Border  \
# 346723    Trout River      New York        715  US-Canada Border
# 346724      Otay Mesa    California       2506  US-Mexico Border
# 346725      Northgate  North Dakota       3406  US-Canada Border
# 346726         Turner       Montana       3306  US-Canada Border
# 346727      Fort Kent         Maine        110  US-Canada Border
# 346728         Norton       Vermont        211  US-Canada Border
# 346729       Columbus    New Mexico       2406  US-Mexico Border
# 346730       Hansboro  North Dakota       3415  US-Canada Border
# 346731  Calexico East    California       2507  US-Mexico Border
# 346732       Presidio         Texas       2403  US-Mexico Border
#
#                           Date                      Measure  Value  \
# 346723  01/01/1996 12:00:00 AM                  Pedestrians     12
# 346724  01/01/1996 12:00:00 AM       Truck Containers Empty  20862
# ...

# %%
#number of observations
df.shape
# Out:
# (346733, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346733 entries, 0 to 346732
# Data columns (total 8 columns):
# Port Name    346733 non-null object
# State        346733 non-null object
# Port Code    346733 non-null int64
# Border       346733 non-null object
# Date         346733 non-null object
# Measure      346733 non-null object
# Value        346733 non-null int64
# Location     346733 non-null object
# dtypes: int64(2), object(6)
# memory usage: 21.2+ MB

# %%
#how is dataset indexed

df.index
# Out:
# RangeIndex(start=0, stop=346733, step=1)

# %%
#columns info
df.columns
# Out:
# Index(['Port Name', 'State', 'Port Code', 'Border', 'Date', 'Measure', 'Value',
#        'Location'],
#       dtype='object')

# %%
#datatypes of columns
df.dtypes
# Out:
# Port Name    object
# State        object
# Port Code     int64
# Border       object
# Date         object
# Measure      object
# Value         int64
# Location     object
# dtype: object

# %%
#check number of borders
borders = data.Border.unique()
borders
# Out:
# array(['US-Mexico Border', 'US-Canada Border'], dtype=object)

# %%
#Check unique elements in portnames, portcodes, location
print(df['Port Name'].unique())
print(len(df['Port Name'].unique()))
# Out:
# ['Calexico East' 'Van Buren' 'Otay Mesa' 'Nogales' 'Trout River'
#  'Madawaska' 'Pembina' 'Progreso' 'Portal' 'Champlain-Rouses Point'
#  'Opheim' 'Neche' 'Lancaster' 'Derby Line' 'Sarles' 'Wildhorse' 'Lynden'
#  'Vanceboro' 'San Ysidro' 'Scobey' 'Beecher Falls' 'Calais' 'Massena'
#  'Oroville' 'Hansboro' 'Ferry' 'Tecate' 'Eastport' 'Walhalla' 'Roma'
#  'Naco' 'Boquillas' 'Raymond' 'Porthill' 'Norton' 'Sault Sainte Marie'
#  'Antler' 'Rio Grande City' 'Del Rio' 'Sasabe' 'Highgate Springs-Alburg'
#  'Del Bonita' 'Houlton' 'Metaline Falls' 'Fort Fairfield' 'Noonan'
#  'Westhope' 'Blaine' 'Douglas' 'Port Huron' 'Bridgewater' 'Santa Teresa'
#  'Lukeville' 'Roseau' 'Skagway' 'Fortuna' 'Frontier' 'Baudette'
#  'Fort Kent' 'Grand Portage' 'Buffalo-Niagara Falls' 'Calexico'
#  'Pinecreek' 'Northgate' 'Sherwood' 'Laurier' 'Detroit' 'Jackman'
#  'Ambrose' 'Turner' 'Dunseith' 'Boundary' 'Sumas' 'Alexandria Bay'
#  'Eagle Pass' 'Carbury' 'Sweetgrass' 'Piegan' 'Tornillo-Fabens' 'El Paso'
# ...

# %%
print(len(df['Port Code'].unique()))
# Out:
# 117

# %%
print(len(df['Location'].unique()))
# Out:
# 224

# %%
#ports with highest number of border crosses
df['Port Name'].value_counts().head(10)
# Out:
# Eastport                  5541
# Buffalo-Niagara Falls     3348
# Portal                    3348
# Nogales                   3348
# El Paso                   3348
# Sweetgrass                3348
# Sumas                     3348
# Champlain-Rouses Point    3348
# Calexico East             3348
# Calais                    3348
# Name: Port Name, dtype: int64

# %%
#total number of border crosses at CANADA and MEXICO borders

df.Border.value_counts()
# Out:
# US-Canada Border    266187
# US-Mexico Border     80546
# Name: Border, dtype: int64

# %%
#time at which highest crossing occurred
df.Date.value_counts().head(10)
# Out:
# 08/01/2010 12:00:00 AM    1356
# 06/01/2010 12:00:00 AM    1356
# 09/01/2010 12:00:00 AM    1356
# 07/01/2010 12:00:00 AM    1356
# 05/01/2010 12:00:00 AM    1356
# 10/01/2010 12:00:00 AM    1356
# 10/01/2006 12:00:00 AM    1344
# 07/01/2006 12:00:00 AM    1344
# 11/01/2010 12:00:00 AM    1344
# 05/01/2006 12:00:00 AM    1344
# Name: Date, dtype: int64

# %%
#Type of crossings

df.Measure.value_counts().head(10)
# Out:
# Personal Vehicles              30219
# Personal Vehicle Passengers    30196
# Trucks                         29856
# Truck Containers Empty         29757
# Truck Containers Full          29694
# Buses                          28822
# Bus Passengers                 28820
# Pedestrians                    28697
# Trains                         27708
# Rail Containers Empty          27684
# Name: Measure, dtype: int64

# %%
#summarize all columns
df.describe(include='all')
# Out:
#        Port Name         State      Port Code            Border  \
# count     346733        346733  346733.000000            346733
# unique       116            15            NaN                 2
# top     Eastport  North Dakota            NaN  US-Canada Border
# freq        5541         57071            NaN            266187
# mean         NaN           NaN    2455.504910               NaN
# std          NaN           NaN    1201.208459               NaN
# min          NaN           NaN     101.000000               NaN
# 25%          NaN           NaN    2304.000000               NaN
# 50%          NaN           NaN    3013.000000               NaN
# 75%          NaN           NaN    3402.000000               NaN
# max          NaN           NaN    4105.000000               NaN
#
#                           Date            Measure         Value  \
# count                   346733             346733  3.467330e+05
# unique                     279                 12           NaN
# ...
