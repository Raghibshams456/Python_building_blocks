# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'Zoo_Animals.csv')

# %%
data.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      turtle     0         0     1     0         0        1         0
# 1   chameleon     0         0     1     0         0        0         0
# 2      iguana     0         0     1     0         0        0         1
# 3      lizard     0         0     1     0         0        0         1
# 4       gecko     0         0     1     0         0        0         0
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        0         1         1         0     0     4     1         1        1
# 1        1         1         1         0     0     4     1         1        0
# 2        1         1         1         0     0     4     1         1        1
# 3        1         1         1         0     0     4     1         0        0
# 4        1         1         1         0     0     4     1         1        0
#
#    class_type
# 0           3
# 1           3
# 2           3
# ...

# %%
#Set animal_name as index

data=data.set_index('animal_name')

# %%
data.describe()
# Out:
#             hair  feathers  eggs  milk   airborne    aquatic   predator  \
# count  43.000000      43.0  43.0  43.0  43.000000  43.000000  43.000000
# mean    0.023256       0.0   1.0   0.0   0.162791   0.465116   0.302326
# std     0.152499       0.0   0.0   0.0   0.373544   0.504685   0.464701
# min     0.000000       0.0   1.0   0.0   0.000000   0.000000   0.000000
# 25%     0.000000       0.0   1.0   0.0   0.000000   0.000000   0.000000
# 50%     0.000000       0.0   1.0   0.0   0.000000   0.000000   0.000000
# 75%     0.000000       0.0   1.0   0.0   0.000000   1.000000   1.000000
# max     1.000000       0.0   1.0   0.0   1.000000   1.000000   1.000000
#
#          toothed   backbone   breathes   venomous       fins       legs  \
# count  43.000000  43.000000  43.000000  43.000000  43.000000  43.000000
# mean    0.441860   0.581395   0.767442   0.116279   0.162791   3.209302
# std     0.502486   0.499169   0.427463   0.324353   0.373544   2.587131
# ...

# %%
data.corr()
# Out:
#                 hair  feathers  eggs  milk  airborne   aquatic  predator  \
# hair        1.000000       NaN   NaN   NaN  0.349927 -0.143889 -0.101575
# feathers         NaN       NaN   NaN   NaN       NaN       NaN       NaN
# eggs             NaN       NaN   NaN   NaN       NaN       NaN       NaN
# milk             NaN       NaN   NaN   NaN       NaN       NaN       NaN
# airborne    0.349927       NaN   NaN   NaN  1.000000 -0.411196 -0.015949
# aquatic    -0.143889       NaN   NaN   NaN -0.411196  1.000000 -0.207765
# predator   -0.101575       NaN   NaN   NaN -0.015949 -0.207765  1.000000
# toothed    -0.137292       NaN   NaN   NaN -0.392346  0.109171  0.433947
# backbone   -0.181848       NaN   NaN   NaN -0.519675  0.507723  0.147997
# breathes    0.084941       NaN   NaN   NaN  0.242740 -0.590326  0.242510
# venomous   -0.055972       NaN   NaN   NaN  0.036561 -0.192805  0.393074
# fins       -0.068041       NaN   NaN   NaN -0.194444  0.472875 -0.153112
# ...

# %%
corr=data.corr()
corr[corr != 1][abs(corr) > 0.7].dropna(how='all', axis=1).dropna(how='all', axis=0)
# Out:
#             backbone  breathes      fins      tail  class_type
# backbone         NaN       NaN       NaN  0.829019   -0.878180
# breathes         NaN       NaN -0.801041       NaN         NaN
# fins             NaN -0.801041       NaN       NaN         NaN
# tail        0.829019       NaN       NaN       NaN   -0.887657
# class_type -0.878180       NaN       NaN -0.887657         NaN

# %%
data.groupby('class_type').mean()
# Out:
#                 hair  feathers  eggs  milk  airborne   aquatic  predator  \
# class_type
# 3           0.000000       0.0   1.0   0.0  0.000000  0.333333  0.666667
# 4           0.000000       0.0   1.0   0.0  0.000000  1.000000  0.142857
# 5           0.000000       0.0   1.0   0.0  0.000000  1.000000  0.000000
# 6           0.083333       0.0   1.0   0.0  0.583333  0.000000  0.250000
# 7           0.000000       0.0   1.0   0.0  0.000000  0.500000  0.166667
#
#              toothed  backbone  breathes  venomous  fins      legs      tail  \
# class_type
# 3           0.916667       1.0       1.0  0.166667   0.0  3.000000  1.000000
# 4           0.142857       1.0       0.0  0.000000   1.0  0.000000  1.000000
# 5           1.000000       1.0       1.0  0.000000   0.0  3.666667  0.333333
# 6           0.000000       0.0       1.0  0.083333   0.0  6.000000  0.000000
# 7           0.166667       0.0       0.5  0.333333   0.0  1.333333  0.000000
#
#             domestic   catsize
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="white", color_codes=True)

# %%
# 1-7 is Mammal, Bird, Reptile, Fish, Amphibian, Bug and Invertebrate
animal_type = ['Mammal', 'Bird', 'Reptile', 'Fish', 'Amphibian', 'Bug', 'Invertebrate']

data['class_name'] = data['class_type'].map(lambda x: animal_type[x-1])

data.iloc[:,-2:].head()
# Out:
#              class_type class_name
# animal_name
# turtle                3    Reptile
# chameleon             3    Reptile
# iguana                3    Reptile
# lizard                3    Reptile
# gecko                 3    Reptile

# %%
data['class_type'].value_counts()
# Out:
# 6    12
# 3    12
# 4     7
# 7     6
# 5     6
# Name: class_type, dtype: int64

# %%
sns.countplot(data['class_name'])

# %%
data.legs.unique()
# Out:
# array([4, 0, 2, 6, 8], dtype=int64)

# %%
sns.countplot(data['legs'])

# %%
plt.figure(figsize=(14,14))
sns.heatmap(data.corr(), annot=True, fmt='.2f')

# %%
data.groupby('class_name').mean()
# Out:
#                   hair  feathers  eggs  milk  airborne   aquatic  predator  \
# class_name
# Amphibian     0.000000       0.0   1.0   0.0  0.000000  1.000000  0.000000
# Bug           0.083333       0.0   1.0   0.0  0.583333  0.000000  0.250000
# Fish          0.000000       0.0   1.0   0.0  0.000000  1.000000  0.142857
# Invertebrate  0.000000       0.0   1.0   0.0  0.000000  0.500000  0.166667
# Reptile       0.000000       0.0   1.0   0.0  0.000000  0.333333  0.666667
#
#                toothed  backbone  breathes  venomous  fins      legs  \
# class_name
# Amphibian     1.000000       1.0       1.0  0.000000   0.0  3.666667
# Bug           0.000000       0.0       1.0  0.083333   0.0  6.000000
# Fish          0.142857       1.0       0.0  0.000000   1.0  0.000000
# Invertebrate  0.166667       0.0       0.5  0.333333   0.0  1.333333
# Reptile       0.916667       1.0       1.0  0.166667   0.0  3.000000
#
#                   tail  domestic   catsize  class_type
# class_name
# ...

# %%
g = sns.FacetGrid(data, col="class_name")
g.map(plt.hist, "legs")
plt.show()
